# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Datasets_Paralelos/GAA.csv')
df
# Out:
#       Unnamed: 0   Tiempos
# 0              0  0.000146
# 1              1  0.000083
# 2              2  0.000084
# 3              3  0.000125
# 4              4  0.000101
# ...          ...       ...
# 9995        9995  0.000059
# 9996        9996  0.000062
# 9997        9997  0.000064
# 9998        9998  0.000060
# 9999        9999  0.000060
#
# [10000 rows x 2 columns]

# %%
df = df.rename(columns={'Unnamed: 0':'indice'})

# %%
df
# Out:
#       indice   Tiempos
# 0          0  0.000146
# 1          1  0.000083
# 2          2  0.000084
# 3          3  0.000125
# 4          4  0.000101
# ...      ...       ...
# 9995    9995  0.000059
# 9996    9996  0.000062
# 9997    9997  0.000064
# 9998    9998  0.000060
# 9999    9999  0.000060
#
# [10000 rows x 2 columns]

# %%
plt.rcParams["figure.autolayout"] = True
x = df['indice'].tolist()
y = df['Tiempos'].tolist()
default_x_ticks = range(len(x))
plt.title('Pruebas con Matrices 10x10')
plt.xlabel('Número de ejecuciones')
plt.ylabel('Tiempo de Ejecución')
plt.plot(default_x_ticks, y)
plt.xticks(default_x_ticks, x)
plt.show()
