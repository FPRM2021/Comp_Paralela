# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Datasets_Paralelos/GAA3.csv')
df
# Out:
#       Unnamed: 0   Tiempos
# 0              0  0.000344
# 1              1  0.000281
# 2              2  0.000319
# 3              3  0.000270
# 4              4  0.000269
# ...          ...       ...
# 9995        9995  0.000274
# 9996        9996  0.000273
# 9997        9997  0.000270
# 9998        9998  0.000277
# 9999        9999  0.000273
#
# [10000 rows x 2 columns]

# %%
df = df.rename(columns={'Unnamed: 0':'indice'})

# %%
df
# Out:
#       indice   Tiempos
# 0          0  0.000344
# 1          1  0.000281
# 2          2  0.000319
# 3          3  0.000270
# 4          4  0.000269
# ...      ...       ...
# 9995    9995  0.000274
# 9996    9996  0.000273
# 9997    9997  0.000270
# 9998    9998  0.000277
# 9999    9999  0.000273
#
# [10000 rows x 2 columns]

# %%
plt.rcParams["figure.autolayout"] = True
x = df['indice'].tolist()
y = df['Tiempos'].tolist()
default_x_ticks = range(len(x))
plt.title('Pruebas con Matrices 200x200')
plt.xlabel('Número de Ejecuciones')
plt.ylabel('Tiempo de Ejecución')
plt.plot(default_x_ticks, y)
plt.xticks(default_x_ticks, x)
plt.show()
