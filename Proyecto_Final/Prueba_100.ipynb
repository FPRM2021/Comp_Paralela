# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Datasets_Paralelos/GAA2.csv')
df
# Out:
#       Unnamed: 0   Tiempos
# 0              0  0.000182
# 1              1  0.000171
# 2              2  0.000130
# 3              3  0.000145
# 4              4  0.000129
# ...          ...       ...
# 9995        9995  0.000127
# 9996        9996  0.000141
# 9997        9997  0.000136
# 9998        9998  0.000128
# 9999        9999  0.000129
#
# [10000 rows x 2 columns]

# %%
df = df.rename(columns={'Unnamed: 0':'indice'})

# %%
df
# Out:
#       indice   Tiempos
# 0          0  0.000182
# 1          1  0.000171
# 2          2  0.000130
# 3          3  0.000145
# 4          4  0.000129
# ...      ...       ...
# 9995    9995  0.000127
# 9996    9996  0.000141
# 9997    9997  0.000136
# 9998    9998  0.000128
# 9999    9999  0.000129
#
# [10000 rows x 2 columns]

# %%
plt.rcParams["figure.autolayout"] = True
x = df['indice'].tolist()
y = df['Tiempos'].tolist()
default_x_ticks = range(len(x))
plt.title('Pruebas con Matrices 100x100')
plt.xlabel('Número de Ejecuciones')
plt.ylabel('Tiempo de Ejecución')
plt.plot(default_x_ticks, y)
plt.xticks(default_x_ticks, x)
plt.show()
